# %%
from linkedin_scrapper import Person
from selenium import webdriver
driver = webdriver.Chrome(r"C:\Users\monis\Downloads\chromedriver_win32\chromedriver.exe")

email = "monishverchandrasekaran@gmail.com"
password = "*********"
#actions.login(driver, email, password) # if email and password isnt given, it'll prompt in terminal
person = Person("http://www.linkedin.com/in/monishver-chandrasekaran-1663981a5/",)
print(person)

# %%
print(person.__dict__)
# Out:
# {'driver': 'http://www.linkedin.com/in/monishver-chandrasekaran-1663981a5/'}

# %%
print(person.driver)
# Out:
# http://www.linkedin.com/in/monishver-chandrasekaran-1663981a5/

# %%
#http://learn.leighcotnoir.com/artspeak/elements-color/hue-value-saturation/

#https://levelup.gitconnected.com/linkedin-scrapper-a3e6790099b5

#https://federicohaag.medium.com/linkedin-scraping-with-python-d8d14519602d

# %%
from bs4 import BeautifulSoup
import requests
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'}
url = 'https://scholar.google.com/scholar?hl=en&as_sdt=0%2C5&q=web+scraping&btnG='
response=requests.get(url,headers=headers)
soup=BeautifulSoup(response.content,'lxml')

# %%
from bs4 import BeautifulSoup 
import requests 
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'} 
url = 'https://scholar.google.com/scholar?hl=en&as_sdt=0%2C5&q=web+scraping&btnG=' 
response=requests.get(url,headers=headers) 
soup=BeautifulSoup(response.content,'lxml') 
#print(soup.select('[data-lid]')) 
for item in soup.select('[data-lid]'): 
    try: 
        print('----------------------------------------') 
        #print(item) 
        #print(item.select('h3')[0].get_text()) 
        #print(item.select('a')[0]['href']) 
        print(item.select('.gs_rs')[0].get_text()) 
        print('----------------------------------------') 
    except Exception as e: 
            raise e 
            print('')
# Out:
# ----------------------------------------
# If programming is magic then web scraping is surely a form of wizardry. By writing a simple automated program, you can query web servers, request data, and parse it to extract the information you need. The expanded edition of this practical book not only introduces you …
# ----------------------------------------
# ----------------------------------------
# Web services are the de facto standard in biomedical data integration. However, there are data integration scenarios that cannot be fully covered by Web services. A number of Web databases and tools do not support Web services, and existing Web services do not cover …
# ----------------------------------------
# ----------------------------------------
# ...

# %%
from bs4 import BeautifulSoup 
import requests 
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'} 

url = 'https://scholar.google.com/scholar?hl=en&as_sdt=0%2C5&q=anisha+radhakrishnan&btnG=&oq=anisha+radha' 
response=requests.get(url,headers=headers) 
soup=BeautifulSoup(response.content,'lxml') 

print(soup.select('.gs_rt2')[0].get_text())
#print(soup.select('.gs_nph')[3].get_text())
article = ''
for i in soup.findAll('div'):
    article = article  +  i.text 
    print(i.text)

#print(article)
#print(item.select('tr'))

#print(soup.select('[data-lid]')) 
for item in soup.select('[data-lid]'): 
    try: 
        print('----------------------------------------') 
        #print(item) 
        #print(item.select('td'))
         
        print(item.select('h3')[0].get_text()) 
        print(item.select('a')[0]['href']) 
        print(item.select('.gs_rs')[0].get_text()) 
        print('----------------------------------------') 
    except Exception as e: 
            raise e 
            print('')
# Out:
# Anisha Radhakrishnan
# ...

# %% [markdown]
# #### College Website scraping

# %%
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'} 
url = 'https://www.amrita.edu/faculty/k-raghesh'
url1 = 'https://www.amrita.edu/faculty/r-anisha' 
response=requests.get(url,headers=headers) 
soup=BeautifulSoup(response.content,'lxml')

# %%
content = soup.find('div', {"class": "row page-header"})
#print(content.get_text())

name = ''
for i in content.findAll('h1'):
    name = name + ' ' +  i.text
    break;

work = ''
for i in content.findAll('h5'):
    work = work + ' ' +  i.text
    break;

name_position = name.strip()
name = name_position.splitlines()[0]
position = name_position.splitlines()[3]
position = position.strip()

print(name)
print(position)
# Out:
# Raghesh Krishnan K.
# Asst. Professor, Computer Science Engineering, School of Engineering, Coimbatore

# %%
content = soup.find('div', {"class": "col-md-9"})
#print(content.get_text())

bio = ''
for i in content.findAll('p'):
    bio = bio + ' ' +  i.text
    break;

print(bio)
# Out:
#  Raghesh Krishnan K. currently serves as Assistant Professor in the department of Computer science, Amrita School of Engineering, Coimbatore Campus. His areas of research include Image Processing and Biomedical Image Classification. .

# %%
content2 = soup.find('div', {"class": "field field-name-field-faculty-qualification field-type-taxonomy-term-reference field-label-inline clearfix"})
print(content2.get_text())

content3 = soup.find('div', {"class": "field field-name-field-faculty-email field-type-text field-label-hidden"})
print(content3.get_text())

content4 = soup.find('div', {"class": "field field-name-field-faculty-research-interest field-type-taxonomy-term-reference field-label-inline clearfix"})
print(content4.get_text())
# Out:
# Qualification: M.Tech
# k_raghesh@cb.amrita.edu
# Faculty Research Interest: Image Processing, Biomedical Image Classification with NLP

# %%
<div class="field field-name-field-faculty-email field-type-text field-label-hidden"><div class="field-items"><div class="field-item even">r_anisha@cb.amrita.edu</div></div></div>

# %%
<div class="field field-name-field-faculty-research-interest field-type-taxonomy-term-reference field-label-inline clearfix"><div class="field-label">Faculty Research Interest:&nbsp;</div><div class="field-items"><div class="field-item even"><a href="/faculty-research-interest/data-structure">Data Structure</a>, <a href="/faculty-research-interest/data-mining">Data Mining</a></div></div></div>

# %%
url2 = 'https://www.amrita.edu/faculty?field_faculty_department_tid=38&field_faculty_designation_tid=97&field_faculty_campus_tid=53&field_faculty_department_main_tid=101&field_center_name_tid=All' 
response=requests.get(url2,headers=headers) 
soup2=BeautifulSoup(response.content,'lxml')

# %%
all_links = [a["href"] for a in soup2.find_all("a", href=True)]
#print(all_links)
faculty_links = []
sub_str = 'faculty'
for i in all_links:
    if (i.find(sub_str) == 1):
        faculty_links.append(i)
    
faculty_links = list(set(faculty_links))
faculty_links.remove('/faculty')
print(faculty_links)
# Out:
# ['/faculty/m-sethu', '/faculty/p-latha', '/faculty/pn-kumar', '/faculty/n-radhika', '/faculty/b-vidhya']

# %%
name_of_faculty = []
position_of_faculty = []
bio_of_faculty = []
qualification_of_faculty = []
mail_of_faculty = []
faculty_research_interest = []

for link in faculty_links:
    url = 'https://www.amrita.edu'+link
    response=requests.get(url,headers=headers) 
    soup=BeautifulSoup(response.content,'lxml')
    
    content1 = soup.find('div', {"class": "row page-header"})
    names = ''
    for i in content1.findAll('h1'):
        names = names + ' ' +  i.text
        break;
    name_position = names.strip()
    name = name_position.splitlines()[0]
    name_of_faculty.append(name)
    
    position = name_position.splitlines()[3]
    position = position.strip()
    position_of_faculty.append(position)
    
    content2 = soup.find('div', {"class": "col-md-9"})
    bio = ''
    for i in content2.findAll('p'):
        bio = bio + ' ' +  i.text
        break;
    bio_of_faculty.append(bio)
    
    content3 = soup.find('div', {"class": "field field-name-field-faculty-qualification field-type-taxonomy-term-reference field-label-inline clearfix"})
    #text3 = content2.get_text()
    qualification = content2.get_text()
    qualification = qualification[15:]
    qualification_of_faculty.append(qualification)
    
    content4 = soup.find('div', {"class": "field field-name-field-faculty-email field-type-text field-label-hidden"})
    mail = content4.get_text()
    mail_of_faculty.append(mail)
    
    content5 = soup.find('div', {"class": "field field-name-field-faculty-research-interest field-type-taxonomy-term-reference field-label-inline clearfix"})
    research_field = content5.get_text()
    research_field = research_field[27:]
    faculty_research_interest.append(research_field)

# %%
print(name_of_faculty[0])
print(position_of_faculty[0])
print(bio_of_faculty[0])
print(qualification_of_faculty[0])
print(mail_of_faculty[0])
print(faculty_research_interest[0])
